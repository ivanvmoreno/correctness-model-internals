# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.rcParams.update({
    'font.family': 'serif',  # or 'sans-serif'
    'font.size': 10,         # base font size
    'axes.labelsize': 10,    # axis label size
    'axes.titlesize': 12,    # title size
    'xtick.labelsize': 8,    # x-axis tick label size
    'ytick.labelsize': 8,    # y-axis tick label size
    'legend.fontsize': 8,    # legend font size
})

DATASET_COLORS = {
    "trivia_qa_2_60k": "#000000",    # black
    "cities_10k": "#e41a1c",         # red
    "gsm8k": "#4daf4a",              # green
    "math_operations_6k": "#377eb8",  # darker yellow (gold)
    "medals_9k": "#ff7f00",          # orange
    "birth_years_4k": "#984ea3",     # purple
}
DATASET_MARKERS = {
    "trivia_qa_2_60k": "o",    # circle
    "cities_10k": "s",          # square
    "gsm8k": "D",              # diamond
    "math_operations_6k": "^",  # triangle up
    "medals_9k": "X",          # uppercase X for thicker x
    "birth_years_4k": "P",      # uppercase P for thicker plus
}


qwen_2_7b_stats_file = "../best_layer_finding/qwen_2.5_7b_instruct/classification_data/train_test_data.csv"
qwen_32b_stats_file = "../best_layer_finding/deepseek_qwen_32b/classification_data/train_test_data.csv"
llama3_8b_stats_file = "../best_layer_finding/llama3.1_8b_chat/classification_data/train_test_data.csv"
llama3_70b_stats_file = "../best_layer_finding/llama3.3_70b/classification_data/train_test_data.csv"
mistral_8b_stats_file = "../best_layer_finding/ministral_8b_instruct/classification_data/train_test_data.csv"
mistral_7b_stats_file = "../best_layer_finding/mistral_7b_instruct/classification_data/res_df_train_test_different_datasets.csv"

LAYER_COUNTS = dict(
    qwen_2_7b_n_layers = 28,
    qwen_32b_n_layers = 64,
    llama3_8b_n_layers = 32,
    llama3_70b_n_layers = 80,
    mistral_8b_n_layers = 36, # ministral
    mistral_7b_n_layers = 32
)

DATASET_NAME_MAP = {
    "trivia_qa_2_60k": "TriviaQA 2 60k",
    "cities_10k": "Cities 10k",
    "gsm8k": "GSM8k",
    "math_operations_6k": "Math Operations 6k",
    "medals_9k": "Medals 9k",
    "birth_years_4k": "Birth Years 4k",
}

# %%
def clean_datset(df):
    df["prompt_id_train"] = df["prompt_id_train"].str.replace("base_3_shot", "base")
    df["prompt_id_test"] = df["prompt_id_test"].str.replace("base_3_shot", "base")
    df = df[df["prompt_id_train"] == "base"]
    df = df[df["prompt_id_test"] == "base"]
    return df

# %%
qwen_2_7b_stats_df = clean_datset(pd.read_csv(qwen_2_7b_stats_file))
qwen_2_7b_stats_df
# Out:
#             model_id_train dataset_id_train prompt_id_train subset_id_train  \
# 0     qwen_2.5_7b_instruct   birth_years_4k            base            main
# 1     qwen_2.5_7b_instruct   birth_years_4k            base            main
# 2     qwen_2.5_7b_instruct   birth_years_4k            base            main
# 3     qwen_2.5_7b_instruct   birth_years_4k            base            main
# 4     qwen_2.5_7b_instruct   birth_years_4k            base            main
# ...                    ...              ...             ...             ...
# 2515  qwen_2.5_7b_instruct  trivia_qa_2_60k            base            main
# 2516  qwen_2.5_7b_instruct  trivia_qa_2_60k            base            main
# 2517  qwen_2.5_7b_instruct  trivia_qa_2_60k            base            main
# 2518  qwen_2.5_7b_instruct  trivia_qa_2_60k            base            main
# 2519  qwen_2.5_7b_instruct  trivia_qa_2_60k            base            main
#
#      input_type_train         model_id_test  dataset_id_test prompt_id_test  \
# 0         prompt_only  qwen_2.5_7b_instruct   birth_years_4k           base
# 1         prompt_only  qwen_2.5_7b_instruct   birth_years_4k           base
# 2         prompt_only  qwen_2.5_7b_instruct   birth_years_4k           base
# 3         prompt_only  qwen_2.5_7b_instruct   birth_years_4k           base
# 4         prompt_only  qwen_2.5_7b_instruct   birth_years_4k           base
# ...               ...                   ...              ...            ...
# 2515      prompt_only  qwen_2.5_7b_instruct  trivia_qa_2_60k           base
# 2516      prompt_only  qwen_2.5_7b_instruct  trivia_qa_2_60k           base
# 2517      prompt_only  qwen_2.5_7b_instruct  trivia_qa_2_60k           base
# 2518      prompt_only  qwen_2.5_7b_instruct  trivia_qa_2_60k           base
# 2519      prompt_only  qwen_2.5_7b_instruct  trivia_qa_2_60k           base
#
#      subset_id_test input_type_test  ...  \
# 0              main     prompt_only  ...
# 1              main     prompt_only  ...
# 2              main     prompt_only  ...
# 3              main     prompt_only  ...
# 4              main     prompt_only  ...
# ...             ...             ...  ...
# 2515           main     prompt_only  ...
# 2516           main     prompt_only  ...
# 2517           main     prompt_only  ...
# 2518           main     prompt_only  ...
# 2519           main     prompt_only  ...
#
#       direction__center_from_origin_True__classifier_cut_zero__optimal_train_set_cut  \
# 0                                             -0.364576
# 1                                             -0.622863
# 2                                             -0.451213
# 3                                             -0.107710
# 4                                              0.022207
# ...                                                 ...
# 2515                                         147.515381
# 2516                                         144.863129
# 2517                                         148.566666
# 2518                                         147.850266
# 2519                                         149.214172
#
#       direction__center_from_origin_True__classifier_cut_zero__test_roc_auc  \
# 0                                              0.547436
# 1                                              0.569855
# 2                                              0.569530
# 3                                              0.568418
# 4                                              0.578467
# ...                                                 ...
# 2515                                           0.721544
# 2516                                           0.716521
# 2517                                           0.724684
# 2518                                           0.713317
# 2519                                           0.725084
#
#       direction__center_from_origin_True__classifier_cut_zero__train_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.542148
# 4                                              0.558667
# ...                                                 ...
# 2515                                           0.515637
# 2516                                           0.515593
# 2517                                           0.515566
# 2518                                           0.515891
# 2519                                           0.515706
#
#       direction__center_from_origin_True__classifier_cut_zero__test_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.545337
# 4                                              0.556022
# ...                                                 ...
# 2515                                           0.516915
# 2516                                           0.513414
# 2517                                           0.517377
# 2518                                           0.514203
# 2519                                           0.516040
#
#       direction__center_from_origin_True__classifier_cut_zero__train_f1_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.327509
# 4                                              0.468273
# ...                                                 ...
# 2515                                           0.673211
# 2516                                           0.673300
# 2517                                           0.673265
# 2518                                           0.673392
# 2519                                           0.673306
#
#       direction__center_from_origin_True__classifier_cut_zero__test_f1_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.328872
# 4                                              0.472546
# ...                                                 ...
# 2515                                           0.674052
# 2516                                           0.672156
# 2517                                           0.673919
# 2518                                           0.672646
# 2519                                           0.673570
#
#       direction__center_from_origin_True__classifier_cut_zero__train_precision_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.616541
# 4                                              0.588889
# ...                                                 ...
# 2515                                           0.507960
# 2516                                           0.507934
# 2517                                           0.507920
# 2518                                           0.508089
# 2519                                           0.507993
#
#       direction__center_from_origin_True__classifier_cut_zero__test_precision_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.627737
# 4                                              0.581967
# ...                                                 ...
# 2515                                           0.508612
# 2516                                           0.506815
# 2517                                           0.508865
# 2518                                           0.507217
# 2519                                           0.508162
#
#       direction__center_from_origin_True__classifier_cut_zero__train_recall_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.222978
# 4                                              0.388667
# ...                                                 ...
# 2515                                           0.997826
# 2516                                           0.998320
# 2517                                           0.998215
# 2518                                           0.998122
# 2519                                           0.998117
#
#       direction__center_from_origin_True__classifier_cut_zero__test_recall_score
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.222798
# 4                                              0.397759
# ...                                                 ...
# 2515                                           0.999005
# 2516                                           0.997615
# 2517                                           0.997447
# 2518                                           0.998212
# 2519                                           0.998622
#
# [2520 rows x 56 columns]

# %%
qwen_32b_stats_df = clean_datset(pd.read_csv(qwen_32b_stats_file))
qwen_32b_stats_df
# Out:
#          model_id_train dataset_id_train prompt_id_train subset_id_train  \
# 0     deepseek_qwen_32b   birth_years_4k            base            main
# 1     deepseek_qwen_32b   birth_years_4k            base            main
# 2     deepseek_qwen_32b   birth_years_4k            base            main
# 3     deepseek_qwen_32b   birth_years_4k            base            main
# 4     deepseek_qwen_32b   birth_years_4k            base            main
# ...                 ...              ...             ...             ...
# 2875  deepseek_qwen_32b  trivia_qa_2_60k            base            main
# 2876  deepseek_qwen_32b  trivia_qa_2_60k            base            main
# 2877  deepseek_qwen_32b  trivia_qa_2_60k            base            main
# 2878  deepseek_qwen_32b  trivia_qa_2_60k            base            main
# 2879  deepseek_qwen_32b  trivia_qa_2_60k            base            main
#
#      input_type_train      model_id_test  dataset_id_test prompt_id_test  \
# 0         prompt_only  deepseek_qwen_32b   birth_years_4k           base
# 1         prompt_only  deepseek_qwen_32b   birth_years_4k           base
# 2         prompt_only  deepseek_qwen_32b   birth_years_4k           base
# 3         prompt_only  deepseek_qwen_32b   birth_years_4k           base
# 4         prompt_only  deepseek_qwen_32b   birth_years_4k           base
# ...               ...                ...              ...            ...
# 2875      prompt_only  deepseek_qwen_32b  trivia_qa_2_60k           base
# 2876      prompt_only  deepseek_qwen_32b  trivia_qa_2_60k           base
# 2877      prompt_only  deepseek_qwen_32b  trivia_qa_2_60k           base
# 2878      prompt_only  deepseek_qwen_32b  trivia_qa_2_60k           base
# 2879      prompt_only  deepseek_qwen_32b  trivia_qa_2_60k           base
#
#      subset_id_test input_type_test  ...  \
# 0              main     prompt_only  ...
# 1              main     prompt_only  ...
# 2              main     prompt_only  ...
# 3              main     prompt_only  ...
# 4              main     prompt_only  ...
# ...             ...             ...  ...
# 2875           main     prompt_only  ...
# 2876           main     prompt_only  ...
# 2877           main     prompt_only  ...
# 2878           main     prompt_only  ...
# 2879           main     prompt_only  ...
#
#       direction__center_from_origin_True__classifier_cut_zero__optimal_train_set_cut  \
# 0                                             -1.631041
# 1                                             -5.876939
# 2                                             -1.509443
# 3                                             -2.162062
# 4                                             -2.012828
# ...                                                 ...
# 2875                                         393.660400
# 2876                                         394.703918
# 2877                                         397.493958
# 2878                                         399.870422
# 2879                                         396.351257
#
#       direction__center_from_origin_True__classifier_cut_zero__test_roc_auc  \
# 0                                              0.551967
# 1                                              0.549547
# 2                                              0.547217
# 3                                              0.552650
# 4                                              0.562010
# ...                                                 ...
# 2875                                           0.684686
# 2876                                           0.682813
# 2877                                           0.680303
# 2878                                           0.671168
# 2879                                           0.680368
#
#       direction__center_from_origin_True__classifier_cut_zero__train_accuracy_score  \
# 0                                              0.500290
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500285
# ...                                                 ...
# 2875                                           0.529894
# 2876                                           0.529087
# 2877                                           0.527757
# 2878                                           0.527452
# 2879                                           0.527388
#
#       direction__center_from_origin_True__classifier_cut_zero__test_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500000
# ...                                                 ...
# 2875                                           0.528700
# 2876                                           0.526019
# 2877                                           0.528510
# 2878                                           0.529591
# 2879                                           0.529846
#
#       direction__center_from_origin_True__classifier_cut_zero__train_f1_score  \
# 0                                              0.001161
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.001139
# ...                                                 ...
# 2875                                           0.677027
# 2876                                           0.676909
# 2877                                           0.676248
# 2878                                           0.675903
# 2879                                           0.675911
#
#       direction__center_from_origin_True__classifier_cut_zero__test_f1_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.676564
# 2876                                           0.674944
# 2877                                           0.676187
# 2878                                           0.677775
# 2879                                           0.677377
#
#       direction__center_from_origin_True__classifier_cut_zero__train_precision_score  \
# 0                                              1.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              1.000000
# ...                                                 ...
# 2875                                           0.515642
# 2876                                           0.515189
# 2877                                           0.514477
# 2878                                           0.514327
# 2879                                           0.514290
#
#       direction__center_from_origin_True__classifier_cut_zero__test_precision_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.514992
# 2876                                           0.513578
# 2877                                           0.514910
# 2878                                           0.515414
# 2879                                           0.515589
#
#       direction__center_from_origin_True__classifier_cut_zero__train_recall_score  \
# 0                                              0.000581
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000570
# ...                                                 ...
# 2875                                           0.985452
# 2876                                           0.986612
# 2877                                           0.986414
# 2878                                           0.985498
# 2879                                           0.985664
#
#       direction__center_from_origin_True__classifier_cut_zero__test_recall_score
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.985864
# 2876                                           0.984172
# 2877                                           0.984566
# 2878                                           0.989469
# 2879                                           0.987134
#
# [2880 rows x 56 columns]

# %%
llama3_8b_stats_df = clean_datset(pd.read_csv(llama3_8b_stats_file))
llama3_8b_stats_df
# Out:
#         model_id_train dataset_id_train prompt_id_train subset_id_train  \
# 0     llama3.1_8b_chat   birth_years_4k            base            main
# 1     llama3.1_8b_chat   birth_years_4k            base            main
# 2     llama3.1_8b_chat   birth_years_4k            base            main
# 3     llama3.1_8b_chat   birth_years_4k            base            main
# 4     llama3.1_8b_chat   birth_years_4k            base            main
# ...                ...              ...             ...             ...
# 2875  llama3.1_8b_chat  trivia_qa_2_60k            base            main
# 2876  llama3.1_8b_chat  trivia_qa_2_60k            base            main
# 2877  llama3.1_8b_chat  trivia_qa_2_60k            base            main
# 2878  llama3.1_8b_chat  trivia_qa_2_60k            base            main
# 2879  llama3.1_8b_chat  trivia_qa_2_60k            base            main
#
#      input_type_train     model_id_test  dataset_id_test prompt_id_test  \
# 0         prompt_only  llama3.1_8b_chat   birth_years_4k           base
# 1         prompt_only  llama3.1_8b_chat   birth_years_4k           base
# 2         prompt_only  llama3.1_8b_chat   birth_years_4k           base
# 3         prompt_only  llama3.1_8b_chat   birth_years_4k           base
# 4         prompt_only  llama3.1_8b_chat   birth_years_4k           base
# ...               ...               ...              ...            ...
# 2875      prompt_only  llama3.1_8b_chat  trivia_qa_2_60k           base
# 2876      prompt_only  llama3.1_8b_chat  trivia_qa_2_60k           base
# 2877      prompt_only  llama3.1_8b_chat  trivia_qa_2_60k           base
# 2878      prompt_only  llama3.1_8b_chat  trivia_qa_2_60k           base
# 2879      prompt_only  llama3.1_8b_chat  trivia_qa_2_60k           base
#
#      subset_id_test input_type_test  ...  \
# 0              main     prompt_only  ...
# 1              main     prompt_only  ...
# 2              main     prompt_only  ...
# 3              main     prompt_only  ...
# 4              main     prompt_only  ...
# ...             ...             ...  ...
# 2875           main     prompt_only  ...
# 2876           main     prompt_only  ...
# 2877           main     prompt_only  ...
# 2878           main     prompt_only  ...
# 2879           main     prompt_only  ...
#
#       direction__center_from_origin_True__classifier_cut_zero__optimal_train_set_cut  \
# 0                                              0.317117
# 1                                              0.090621
# 2                                              0.104872
# 3                                              0.194001
# 4                                              0.103900
# ...                                                 ...
# 2875                                          13.645540
# 2876                                          12.834138
# 2877                                          12.531933
# 2878                                          12.893509
# 2879                                          13.027604
#
#       direction__center_from_origin_True__classifier_cut_zero__test_roc_auc  \
# 0                                              0.591822
# 1                                              0.562054
# 2                                              0.557533
# 3                                              0.493205
# 4                                              0.535745
# ...                                                 ...
# 2875                                           0.769617
# 2876                                           0.778130
# 2877                                           0.763429
# 2878                                           0.774424
# 2879                                           0.774713
#
#       direction__center_from_origin_True__classifier_cut_zero__train_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500000
# ...                                                 ...
# 2875                                           0.521248
# 2876                                           0.523767
# 2877                                           0.521875
# 2878                                           0.521045
# 2879                                           0.520960
#
#       direction__center_from_origin_True__classifier_cut_zero__test_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500000
# ...                                                 ...
# 2875                                           0.518772
# 2876                                           0.521778
# 2877                                           0.522823
# 2878                                           0.521956
# 2879                                           0.521416
#
#       direction__center_from_origin_True__classifier_cut_zero__train_f1_score  \
# 0                                              0.666667
# 1                                              0.666667
# 2                                              0.666667
# 3                                              0.666667
# 4                                              0.666667
# ...                                                 ...
# 2875                                           0.675692
# 2876                                           0.676358
# 2877                                           0.675621
# 2878                                           0.675268
# 2879                                           0.675299
#
#       direction__center_from_origin_True__classifier_cut_zero__test_f1_score  \
# 0                                              0.666667
# 1                                              0.666667
# 2                                              0.666667
# 3                                              0.666667
# 4                                              0.666667
# ...                                                 ...
# 2875                                           0.674723
# 2876                                           0.675703
# 2877                                           0.675516
# 2878                                           0.675799
# 2879                                           0.675409
#
#       direction__center_from_origin_True__classifier_cut_zero__train_precision_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500000
# ...                                                 ...
# 2875                                           0.510883
# 2876                                           0.512232
# 2877                                           0.511230
# 2878                                           0.510793
# 2879                                           0.510745
#
#       direction__center_from_origin_True__classifier_cut_zero__test_precision_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500000
# ...                                                 ...
# 2875                                           0.509583
# 2876                                           0.511172
# 2877                                           0.511757
# 2878                                           0.511265
# 2879                                           0.510989
#
#       direction__center_from_origin_True__classifier_cut_zero__train_recall_score  \
# 0                                              1.000000
# 1                                              1.000000
# 2                                              1.000000
# 3                                              1.000000
# 4                                              1.000000
# ...                                                 ...
# 2875                                           0.997474
# 2876                                           0.995247
# 2877                                           0.995848
# 2878                                           0.995970
# 2879                                           0.996284
#
#       direction__center_from_origin_True__classifier_cut_zero__test_recall_score
# 0                                              1.000000
# 1                                              1.000000
# 2                                              1.000000
# 3                                              1.000000
# 4                                              1.000000
# ...                                                 ...
# 2875                                           0.998212
# 2876                                           0.996420
# 2877                                           0.993393
# 2878                                           0.996487
# 2879                                           0.995836
#
# [2880 rows x 56 columns]

# %%
llama3_70b_stats_df = clean_datset(pd.read_csv(llama3_70b_stats_file))
llama3_70b_stats_df
# Out:
#      model_id_train dataset_id_train prompt_id_train subset_id_train  \
# 0      llama3.3_70b   birth_years_4k            base            main
# 1      llama3.3_70b   birth_years_4k            base            main
# 2      llama3.3_70b   birth_years_4k            base            main
# 3      llama3.3_70b   birth_years_4k            base            main
# 4      llama3.3_70b   birth_years_4k            base            main
# ...             ...              ...             ...             ...
# 3595   llama3.3_70b  trivia_qa_2_60k            base            main
# 3596   llama3.3_70b  trivia_qa_2_60k            base            main
# 3597   llama3.3_70b  trivia_qa_2_60k            base            main
# 3598   llama3.3_70b  trivia_qa_2_60k            base            main
# 3599   llama3.3_70b  trivia_qa_2_60k            base            main
#
#      input_type_train model_id_test  dataset_id_test prompt_id_test  \
# 0         prompt_only  llama3.3_70b   birth_years_4k           base
# 1         prompt_only  llama3.3_70b   birth_years_4k           base
# 2         prompt_only  llama3.3_70b   birth_years_4k           base
# 3         prompt_only  llama3.3_70b   birth_years_4k           base
# 4         prompt_only  llama3.3_70b   birth_years_4k           base
# ...               ...           ...              ...            ...
# 3595      prompt_only  llama3.3_70b  trivia_qa_2_60k           base
# 3596      prompt_only  llama3.3_70b  trivia_qa_2_60k           base
# 3597      prompt_only  llama3.3_70b  trivia_qa_2_60k           base
# 3598      prompt_only  llama3.3_70b  trivia_qa_2_60k           base
# 3599      prompt_only  llama3.3_70b  trivia_qa_2_60k           base
#
#      subset_id_test input_type_test  ...  \
# 0              main     prompt_only  ...
# 1              main     prompt_only  ...
# 2              main     prompt_only  ...
# 3              main     prompt_only  ...
# 4              main     prompt_only  ...
# ...             ...             ...  ...
# 3595           main     prompt_only  ...
# 3596           main     prompt_only  ...
# 3597           main     prompt_only  ...
# 3598           main     prompt_only  ...
# 3599           main     prompt_only  ...
#
#       direction__center_from_origin_True__classifier_cut_zero__optimal_train_set_cut  \
# 0                                              0.034710
# 1                                             -0.015043
# 2                                             -0.010632
# 3                                              0.000109
# 4                                             -0.007498
# ...                                                 ...
# 3595                                          19.779491
# 3596                                          18.971420
# 3597                                          19.543653
# 3598                                          19.236343
# 3599                                          18.881716
#
#       direction__center_from_origin_True__classifier_cut_zero__test_roc_auc  \
# 0                                              0.574779
# 1                                              0.534777
# 2                                              0.503772
# 3                                              0.613536
# 4                                              0.554820
# ...                                                 ...
# 3595                                           0.821217
# 3596                                           0.823565
# 3597                                           0.796315
# 3598                                           0.830721
# 3599                                           0.833586
#
#       direction__center_from_origin_True__classifier_cut_zero__train_accuracy_score  \
# 0                                              0.514925
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.585000
# 4                                              0.524272
# ...                                                 ...
# 3595                                           0.500000
# 3596                                           0.500000
# 3597                                           0.500000
# 3598                                           0.500000
# 3599                                           0.500000
#
#       direction__center_from_origin_True__classifier_cut_zero__test_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.596154
# 4                                              0.532609
# ...                                                 ...
# 3595                                           0.500000
# 3596                                           0.500000
# 3597                                           0.500000
# 3598                                           0.500000
# 3599                                           0.500000
#
#       direction__center_from_origin_True__classifier_cut_zero__train_f1_score  \
# 0                                              0.672269
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.626126
# 4                                              0.132743
# ...                                                 ...
# 3595                                           0.666667
# 3596                                           0.666667
# 3597                                           0.666667
# 3598                                           0.666667
# 3599                                           0.666667
#
#       direction__center_from_origin_True__classifier_cut_zero__test_f1_score  \
# 0                                              0.666667
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.543478
# 4                                              0.156863
# ...                                                 ...
# 3595                                           0.666667
# 3596                                           0.666667
# 3597                                           0.666667
# 3598                                           0.666667
# 3599                                           0.666667
#
#       direction__center_from_origin_True__classifier_cut_zero__train_precision_score  \
# 0                                              0.507614
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.569672
# 4                                              0.750000
# ...                                                 ...
# 3595                                           0.500000
# 3596                                           0.500000
# 3597                                           0.500000
# 3598                                           0.500000
# 3599                                           0.500000
#
#       direction__center_from_origin_True__classifier_cut_zero__test_precision_score  \
# 0                                                 0.500
# 1                                                 0.000
# 2                                                 0.000
# 3                                                 0.625
# 4                                                 0.800
# ...                                                 ...
# 3595                                              0.500
# 3596                                              0.500
# 3597                                              0.500
# 3598                                              0.500
# 3599                                              0.500
#
#       direction__center_from_origin_True__classifier_cut_zero__train_recall_score  \
# 0                                              0.995025
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.695000
# 4                                              0.072816
# ...                                                 ...
# 3595                                           1.000000
# 3596                                           1.000000
# 3597                                           1.000000
# 3598                                           1.000000
# 3599                                           1.000000
#
#       direction__center_from_origin_True__classifier_cut_zero__test_recall_score
# 0                                              1.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.480769
# 4                                              0.086957
# ...                                                 ...
# 3595                                           1.000000
# 3596                                           1.000000
# 3597                                           1.000000
# 3598                                           1.000000
# 3599                                           1.000000
#
# [3600 rows x 56 columns]

# %%
mistral_8b_stats_df = clean_datset(pd.read_csv(mistral_8b_stats_file))
mistral_8b_stats_df
# Out:
#              model_id_train dataset_id_train prompt_id_train subset_id_train  \
# 0     ministral_8b_instruct   birth_years_4k            base            main
# 1     ministral_8b_instruct   birth_years_4k            base            main
# 2     ministral_8b_instruct   birth_years_4k            base            main
# 3     ministral_8b_instruct   birth_years_4k            base            main
# 4     ministral_8b_instruct   birth_years_4k            base            main
# ...                     ...              ...             ...             ...
# 3235  ministral_8b_instruct  trivia_qa_2_60k            base            main
# 3236  ministral_8b_instruct  trivia_qa_2_60k            base            main
# 3237  ministral_8b_instruct  trivia_qa_2_60k            base            main
# 3238  ministral_8b_instruct  trivia_qa_2_60k            base            main
# 3239  ministral_8b_instruct  trivia_qa_2_60k            base            main
#
#      input_type_train          model_id_test  dataset_id_test prompt_id_test  \
# 0         prompt_only  ministral_8b_instruct   birth_years_4k           base
# 1         prompt_only  ministral_8b_instruct   birth_years_4k           base
# 2         prompt_only  ministral_8b_instruct   birth_years_4k           base
# 3         prompt_only  ministral_8b_instruct   birth_years_4k           base
# 4         prompt_only  ministral_8b_instruct   birth_years_4k           base
# ...               ...                    ...              ...            ...
# 3235      prompt_only  ministral_8b_instruct  trivia_qa_2_60k           base
# 3236      prompt_only  ministral_8b_instruct  trivia_qa_2_60k           base
# 3237      prompt_only  ministral_8b_instruct  trivia_qa_2_60k           base
# 3238      prompt_only  ministral_8b_instruct  trivia_qa_2_60k           base
# 3239      prompt_only  ministral_8b_instruct  trivia_qa_2_60k           base
#
#      subset_id_test input_type_test  ...  \
# 0              main     prompt_only  ...
# 1              main     prompt_only  ...
# 2              main     prompt_only  ...
# 3              main     prompt_only  ...
# 4              main     prompt_only  ...
# ...             ...             ...  ...
# 3235           main     prompt_only  ...
# 3236           main     prompt_only  ...
# 3237           main     prompt_only  ...
# 3238           main     prompt_only  ...
# 3239           main     prompt_only  ...
#
#       direction__center_from_origin_True__classifier_cut_zero__optimal_train_set_cut  \
# 0                                             -0.068876
# 1                                             -0.068263
# 2                                             -0.073091
# 3                                             -0.053610
# 4                                             -0.081533
# ...                                                 ...
# 3235                                           8.940220
# 3236                                           8.869599
# 3237                                           8.711848
# 3238                                           8.828129
# 3239                                           8.953843
#
#       direction__center_from_origin_True__classifier_cut_zero__test_roc_auc  \
# 0                                              0.528094
# 1                                              0.527860
# 2                                              0.558631
# 3                                              0.542944
# 4                                              0.557219
# ...                                                 ...
# 3235                                           0.721608
# 3236                                           0.710195
# 3237                                           0.731092
# 3238                                           0.716290
# 3239                                           0.722214
#
#       direction__center_from_origin_True__classifier_cut_zero__train_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500000
# ...                                                 ...
# 3235                                           0.514383
# 3236                                           0.513659
# 3237                                           0.515018
# 3238                                           0.514094
# 3239                                           0.514999
#
#       direction__center_from_origin_True__classifier_cut_zero__test_accuracy_score  \
# 0                                              0.500000
# 1                                              0.500000
# 2                                              0.500000
# 3                                              0.500000
# 4                                              0.500000
# ...                                                 ...
# 3235                                           0.514943
# 3236                                           0.513866
# 3237                                           0.515539
# 3238                                           0.514689
# 3239                                           0.513659
#
#       direction__center_from_origin_True__classifier_cut_zero__train_f1_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 3235                                           0.672711
# 3236                                           0.672370
# 3237                                           0.672970
# 3238                                           0.672566
# 3239                                           0.672923
#
#       direction__center_from_origin_True__classifier_cut_zero__test_f1_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 3235                                           0.673009
# 3236                                           0.672521
# 3237                                           0.673189
# 3238                                           0.673054
# 3239                                           0.672439
#
#       direction__center_from_origin_True__classifier_cut_zero__train_precision_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 3235                                           0.507310
# 3236                                           0.506937
# 3237                                           0.507639
# 3238                                           0.507162
# 3239                                           0.507630
#
#       direction__center_from_origin_True__classifier_cut_zero__test_precision_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 3235                                           0.507598
# 3236                                           0.507042
# 3237                                           0.507909
# 3238                                           0.507461
# 3239                                           0.506936
#
#       direction__center_from_origin_True__classifier_cut_zero__train_recall_score  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 3235                                           0.998140
# 3236                                           0.998082
# 3237                                           0.998009
# 3238                                           0.998074
# 3239                                           0.997832
#
#       direction__center_from_origin_True__classifier_cut_zero__test_recall_score
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 3235                                           0.998340
# 3236                                           0.998341
# 3237                                           0.997928
# 3238                                           0.999067
# 3239                                           0.998393
#
# [3240 rows x 56 columns]

# %%
mistral_7b_stats_df = clean_datset(pd.read_csv(mistral_7b_stats_file))
mistral_7b_stats_df
# Out:
#            model_id_train dataset_id_train prompt_id_train subset_id_train  \
# 0     mistral_7b_instruct   birth_years_4k            base            main
# 1     mistral_7b_instruct   birth_years_4k            base            main
# 2     mistral_7b_instruct   birth_years_4k            base            main
# 3     mistral_7b_instruct   birth_years_4k            base            main
# 4     mistral_7b_instruct   birth_years_4k            base            main
# ...                   ...              ...             ...             ...
# 2875  mistral_7b_instruct  trivia_qa_2_60k            base            main
# 2876  mistral_7b_instruct  trivia_qa_2_60k            base            main
# 2877  mistral_7b_instruct  trivia_qa_2_60k            base            main
# 2878  mistral_7b_instruct  trivia_qa_2_60k            base            main
# 2879  mistral_7b_instruct  trivia_qa_2_60k            base            main
#
#      input_type_train        model_id_test  dataset_id_test prompt_id_test  \
# 0         prompt_only  mistral_7b_instruct   birth_years_4k           base
# 1         prompt_only  mistral_7b_instruct   birth_years_4k           base
# 2         prompt_only  mistral_7b_instruct   birth_years_4k           base
# 3         prompt_only  mistral_7b_instruct   birth_years_4k           base
# 4         prompt_only  mistral_7b_instruct   birth_years_4k           base
# ...               ...                  ...              ...            ...
# 2875      prompt_only  mistral_7b_instruct  trivia_qa_2_60k           base
# 2876      prompt_only  mistral_7b_instruct  trivia_qa_2_60k           base
# 2877      prompt_only  mistral_7b_instruct  trivia_qa_2_60k           base
# 2878      prompt_only  mistral_7b_instruct  trivia_qa_2_60k           base
# 2879      prompt_only  mistral_7b_instruct  trivia_qa_2_60k           base
#
#      subset_id_test input_type_test  ...  \
# 0              main     prompt_only  ...
# 1              main     prompt_only  ...
# 2              main     prompt_only  ...
# 3              main     prompt_only  ...
# 4              main     prompt_only  ...
# ...             ...             ...  ...
# 2875           main     prompt_only  ...
# 2876           main     prompt_only  ...
# 2877           main     prompt_only  ...
# 2878           main     prompt_only  ...
# 2879           main     prompt_only  ...
#
#       direction__center_from_origin_True__classifier_cut_zero__optimal_train_set_cut  \
# 0                                              0.004379
# 1                                              0.001918
# 2                                             -0.003419
# 3                                              0.004726
# 4                                             -0.006278
# ...                                                 ...
# 2875                                           9.603097
# 2876                                           9.756647
# 2877                                           9.696221
# 2878                                           9.716070
# 2879                                           9.664612
#
#       direction__center_from_origin_True__classifier_cut_zero__test_roc_auc  \
# 0                                              0.555002
# 1                                              0.564952
# 2                                              0.561917
# 3                                              0.521306
# 4                                              0.529948
# ...                                                 ...
# 2875                                           0.760889
# 2876                                           0.764547
# 2877                                           0.763637
# 2878                                           0.766280
# 2879                                           0.771911
#
#       direction__center_from_origin_True__classifier_cut_zero__train_accuracy_score  \
# 0                                              0.500000
# 1                                              0.545749
# 2                                              0.520427
# 3                                              0.506115
# 4                                              0.500000
# ...                                                 ...
# 2875                                           0.519893
# 2876                                           0.520218
# 2877                                           0.519738
# 2878                                           0.519505
# 2879                                           0.518854
#
#       direction__center_from_origin_True__classifier_cut_zero__test_accuracy_score  \
# 0                                              0.500000
# 1                                              0.537037
# 2                                              0.512727
# 3                                              0.494810
# 4                                              0.500000
# ...                                                 ...
# 2875                                           0.519815
# 2876                                           0.519546
# 2877                                           0.518056
# 2878                                           0.518252
# 2879                                           0.521615
#
#       direction__center_from_origin_True__classifier_cut_zero__train_f1_score  \
# 0                                              0.666667
# 1                                              0.489351
# 2                                              0.152584
# 3                                              0.668770
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.674850
# 2876                                           0.674919
# 2877                                           0.674700
# 2878                                           0.674615
# 2879                                           0.674350
#
#       direction__center_from_origin_True__classifier_cut_zero__test_f1_score  \
# 0                                              0.666667
# 1                                              0.500000
# 2                                              0.129870
# 3                                              0.662037
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.675026
# 2876                                           0.674888
# 2877                                           0.673502
# 2878                                           0.673405
# 2879                                           0.675270
#
#       direction__center_from_origin_True__classifier_cut_zero__train_precision_score  \
# 0                                              0.500000
# 1                                              0.558719
# 2                                              0.654930
# 3                                              0.503085
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.510185
# 2876                                           0.510359
# 2877                                           0.510108
# 2878                                           0.509985
# 2879                                           0.509644
#
#       direction__center_from_origin_True__classifier_cut_zero__test_precision_score  \
# 0                                              0.500000
# 1                                              0.543478
# 2                                              0.606061
# 3                                              0.497391
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.510134
# 2876                                           0.509995
# 2877                                           0.509249
# 2878                                           0.509359
# 2879                                           0.511105
#
#       direction__center_from_origin_True__classifier_cut_zero__train_recall_score  \
# 0                                              1.000000
# 1                                              0.435305
# 2                                              0.086351
# 3                                              0.997178
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.996466
# 2876                                           0.996099
# 2877                                           0.996104
# 2878                                           0.996204
# 2879                                           0.996347
#
#       direction__center_from_origin_True__classifier_cut_zero__test_recall_score
# 0                                              1.000000
# 1                                              0.462963
# 2                                              0.072727
# 3                                              0.989619
# 4                                              0.000000
# ...                                                 ...
# 2875                                           0.997427
# 2876                                           0.997359
# 2877                                           0.994158
# 2878                                           0.993316
# 2879                                           0.994792
#
# [2880 rows x 56 columns]

# %%
def find_best_layer(stats_df, metric_name):
    stats_df = stats_df[stats_df["dataset_id_train"] == "trivia_qa_2_60k"]
    stats_df = stats_df[stats_df["dataset_id_test"] == "trivia_qa_2_60k"]
    return stats_df[["layer", metric_name]].groupby("layer")[metric_name].mean().idxmax()

best_layer_qwen_2_7b = find_best_layer(qwen_2_7b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
best_layer_qwen_32b = find_best_layer(qwen_32b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
best_layer_llama3_8b = find_best_layer(llama3_8b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
best_layer_llama3_70b = find_best_layer(llama3_70b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
best_layer_mistral_8b = find_best_layer(mistral_8b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
best_layer_mistral_7b = find_best_layer(mistral_7b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")

best_layer_qwen_2_7b, best_layer_qwen_32b, best_layer_llama3_8b, best_layer_llama3_70b, best_layer_mistral_8b, best_layer_mistral_7b
# todo hard code the total number of layers
# Out:
# (22, 44, 16, 76, 18, 16)

# %%
best_layer_qwen_2_7b / LAYER_COUNTS["qwen_2_7b_n_layers"], best_layer_qwen_32b / LAYER_COUNTS["qwen_32b_n_layers"], best_layer_llama3_8b / LAYER_COUNTS["llama3_8b_n_layers"], best_layer_llama3_70b / LAYER_COUNTS["llama3_70b_n_layers"], best_layer_mistral_8b / LAYER_COUNTS["mistral_8b_n_layers"], best_layer_mistral_7b / LAYER_COUNTS["mistral_7b_n_layers"]
# Out:
# (0.7857142857142857, 0.6875, 0.5, 0.95, 0.5, 0.5)

# %%
def compare_metric_at_specified_layers_across_models_and_datasets(
        model_stats_dict,
        metric_name,
        save_path=None,
        figsize=(6, 10),
    ):
    stats_df_list = []
    for model_name, model_dict in model_stats_dict.items():
        stats_df = model_dict["stats_df"].copy()

        assert stats_df["input_type_train"].nunique() == 1, f"Input type train is not unique for {model_name}"
        assert stats_df["input_type_test"].nunique() == 1, f"Input type test is not unique for {model_name}"
        assert stats_df["prompt_id_train"].nunique() == 1, f"Prompt id train is not unique for {model_name}"
        assert stats_df["prompt_id_test"].nunique() == 1, f"Prompt id test is not unique for {model_name}"

        layer = model_dict["layer"]
        stats_df = stats_df[stats_df['layer'] == layer]
        assert not stats_df.empty, f"Stats df is empty for {model_name}"

        # should have one row per fold per train dataset per test dataset
        assert len(stats_df) == stats_df["fold"].nunique() * stats_df["dataset_id_train"].nunique() * stats_df["dataset_id_test"].nunique(), f"Stats df has wrong number of rows for {model_name}"

        stats_df = stats_df[[
            'dataset_id_train', 'prompt_id_train',
            'subset_id_train', 'model_id_test',
            'dataset_id_test', 'prompt_id_test', 'subset_id_test',
            'fold', metric_name
        ]]
        stats_df["model_name"] = model_name
        stats_df_list.append(stats_df)
    
    stats_df_combined = pd.concat(stats_df_list)

    stats_df_combined = stats_df_combined[["model_name", "fold", "dataset_id_train", "dataset_id_test", metric_name]]

    stats_df_averaged = stats_df_combined.groupby(["model_name", "dataset_id_train", "dataset_id_test"]).mean().reset_index()

    fig, axes = plt.subplots(
        len(stats_df_averaged["dataset_id_train"].unique()),
        1,
        figsize=figsize,
        constrained_layout=True,
    )
    if not isinstance(axes, np.ndarray):
        axes = [axes]
    order_mapping = {value: idx for idx, value in enumerate(model_stats_dict.keys())}
    stats_df_averaged['sort_key'] = stats_df_averaged['model_name'].map(order_mapping)
    stats_df_averaged = stats_df_averaged.sort_values('sort_key').drop(columns=['sort_key'])
    stats_df_averaged["model_name_with_layer"] = stats_df_averaged["model_name"] + "\nLayer " + stats_df_averaged["model_name"].apply(lambda x: model_stats_dict[x]['layer']).astype(str)
    for i, (ax, train_dataset) in enumerate(zip(axes, stats_df_combined["dataset_id_train"].unique())):
        train_df = stats_df_averaged[stats_df_averaged["dataset_id_train"] == train_dataset]
        for test_dataset, test_df in train_df.groupby("dataset_id_test"):
            sns.scatterplot(
                data=test_df,
                x="model_name_with_layer",
                y=metric_name,
                color=DATASET_COLORS[test_dataset],
                marker=DATASET_MARKERS[test_dataset],
                label=DATASET_NAME_MAP[test_dataset],
                ax=ax,
            )

        ax.set_ylim(0.5, 1)
        ax.set_xlabel("")

        ax.grid(True, linestyle='--', alpha=0.3)  # Light grid
        ax.set_facecolor('white') 

        if len(axes) > 1:
            ax.set_ylabel(f"Train: {DATASET_NAME_MAP[train_dataset]}", fontsize=10)
            if i == 0:
                ax.set_title(f"Test ROC AUCs")
            else:
                ax.set_title("")
        else:
            ax.set_ylabel("Test ROC AUC")
            ax.set_title(f"Train on {DATASET_NAME_MAP[train_dataset]} - Test ROC AUCs")
    
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(
        handles, 
        labels,
        loc='center right',  # or 'upper center', 'lower center', etc.
        bbox_to_anchor=(1.15, 0.5),  # Adjust these values to position the legend
        title='Dataset',
        frameon=True
    )
    for ax in axes:
        ax.get_legend().remove()

    

    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right
    if save_path:
        plt.savefig(
            save_path, 
            bbox_inches='tight',
            pad_inches=0.1,
            dpi=300
        )
    plt.show()
    

compare_metric_at_specified_layers_across_models_and_datasets(
    {
        "Mistral 7b": {"stats_df": mistral_7b_stats_df, "layer": best_layer_mistral_7b},
        "Ministral 8b": {"stats_df": mistral_8b_stats_df, "layer": best_layer_mistral_8b},
        "Qwen 2.5 7b": {"stats_df": qwen_2_7b_stats_df, "layer": best_layer_qwen_2_7b},
        "Qwen 32b": {"stats_df": qwen_32b_stats_df, "layer": best_layer_qwen_32b},
        "Llama 3.1 8b": {"stats_df": llama3_8b_stats_df, "layer": best_layer_llama3_8b},
        "Llama 3.3 70b": {"stats_df": llama3_70b_stats_df, "layer": best_layer_llama3_70b},
    },
    metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc",
    figsize=(6, 10),
    save_path="best_layer_model_comparison.pdf"
)


compare_metric_at_specified_layers_across_models_and_datasets(
    {
        "Mistral 7b": {"stats_df": mistral_7b_stats_df[mistral_7b_stats_df["dataset_id_train"] == "trivia_qa_2_60k"], "layer": best_layer_mistral_7b},
        "Ministral 8b": {"stats_df": mistral_8b_stats_df[mistral_8b_stats_df["dataset_id_train"] == "trivia_qa_2_60k"], "layer": best_layer_mistral_8b},
        "Qwen 2.5 7b": {"stats_df": qwen_2_7b_stats_df[qwen_2_7b_stats_df["dataset_id_train"] == "trivia_qa_2_60k"], "layer": best_layer_qwen_2_7b},
        "Qwen 32b": {"stats_df": qwen_32b_stats_df[qwen_32b_stats_df["dataset_id_train"] == "trivia_qa_2_60k"], "layer": best_layer_qwen_32b},
        "Llama 3.1 8b": {"stats_df": llama3_8b_stats_df[llama3_8b_stats_df["dataset_id_train"] == "trivia_qa_2_60k"], "layer": best_layer_llama3_8b},
        "Llama 3.3 70b": {"stats_df": llama3_70b_stats_df[llama3_70b_stats_df["dataset_id_train"] == "trivia_qa_2_60k"], "layer": best_layer_llama3_70b},
    },
    metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc",
    figsize=(6, 4),
    save_path="best_layer_model_comparison_trivia_qa_2_60k.pdf"
)
# Out:
# /var/folders/qd/cz9h19sd335142892r1531f40000gn/T/ipykernel_75749/855980798.py:93: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right
# /var/folders/qd/cz9h19sd335142892r1531f40000gn/T/ipykernel_75749/855980798.py:93: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right

# %%
def heatmap_metric_across_train_test_and_dataset_combinations(model_stats_dict, metric_name, figsize=(6, 4), save_path=None):
    assert len(model_stats_dict) == 1, "Only one model is supported"
    model_name, model_dict = list(model_stats_dict.items())[0]
    stats_df = model_dict["stats_df"].copy()

    assert stats_df["input_type_train"].nunique() == 1, f"Input type train is not unique for {model_name}"
    assert stats_df["input_type_test"].nunique() == 1, f"Input type test is not unique for {model_name}"
    assert stats_df["prompt_id_train"].nunique() == 1, f"Prompt id train is not unique for {model_name}, {stats_df['prompt_id_train'].unique()=}"
    assert stats_df["prompt_id_test"].nunique() == 1, f"Prompt id test is not unique for {model_name}"

    layer = model_dict["layer"]
    stats_df = stats_df[stats_df['layer'] == layer]
    assert not stats_df.empty, f"Stats df is empty for {model_name}"

    # should have one row per fold per train dataset per test dataset
    assert len(stats_df) == stats_df["fold"].nunique() * stats_df["dataset_id_train"].nunique() * stats_df["dataset_id_test"].nunique(), f"Stats df has wrong number of rows for {model_name}"


    stats_df["model_name"] = model_name
    stats_df = stats_df[["model_name", "fold", "dataset_id_train", "dataset_id_test", metric_name]]
    stats_df_averaged = stats_df.groupby(["model_name", "dataset_id_train", "dataset_id_test"]).mean().reset_index()
    stats_df_averaged["dataset_id_train"] = stats_df_averaged["dataset_id_train"].map(DATASET_NAME_MAP)
    stats_df_averaged["dataset_id_test"] = stats_df_averaged["dataset_id_test"].map(DATASET_NAME_MAP)

    heatmap_df = stats_df_averaged.pivot(
        index="dataset_id_train",
        columns="dataset_id_test",
        values=metric_name
    )
    # ax = sns.heatmap(data=heatmap_df, annot=True)
    # ax.set_xlabel("Test Dataset")
    # ax.set_ylabel("Train Dataset")
    # ax.set_title(f"{model_name} - Layer {layer}\nTest ROC AUCs")
    # plt.tight_layout()
    # plt.show()

    plt.figure(figsize=figsize, dpi=300)
    sns.set_style("whitegrid")
    sns.heatmap(
        heatmap_df,
        annot=True,
        fmt='.2f',
        cmap='YlOrRd',
        cbar_kws={'label': 'Test ROC AUC'},
        linewidths=0.5,
        linecolor='gray'
    )
    plt.gca().collections[0].set_clim(0.5, 1.0)  # Set colorbar range from 0.5 to 1.0
    plt.title(f'{model_name} - Layer {layer}', pad=20)
    plt.xlabel('Test Dataset')
    plt.ylabel('Train Dataset')
    plt.yticks(rotation=45, ha='right')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    if save_path:
        plt.savefig(
            save_path, 
            bbox_inches='tight',
            pad_inches=0.1,
            dpi=300
        )
    plt.show()
    

    
heatmap_metric_across_train_test_and_dataset_combinations(
    {
        "Llama 3.3 70b": {"stats_df": llama3_70b_stats_df, "layer": best_layer_llama3_70b},
    },
    metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc",
    figsize=(5, 5),
    save_path="llama_3_70b_best_layer_auc_heatmap.pdf"
)
heatmap_metric_across_train_test_and_dataset_combinations(
    {
        "Mistral 7b": {"stats_df": mistral_7b_stats_df, "layer": best_layer_mistral_7b},
    },
    metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc",
    figsize=(5, 5),
    save_path="mistral_7b_best_layer_auc_heatmap.pdf"
)

# %%
def find_first_good_enough_layer(stats_df, metric_name, threshold=None):
    stats_df = stats_df[stats_df["dataset_id_train"] == "trivia_qa_2_60k"].copy()
    stats_df = stats_df[stats_df["dataset_id_test"] == "trivia_qa_2_60k"]
    means = stats_df[["layer", metric_name]].groupby("layer")[metric_name].mean()
    if threshold is None:
        threshold = means.max() * 0.90
    means = means[means >= threshold].sort_index()
    return means.index[0]

find_first_good_enough_layer_qwen_2_7b = find_first_good_enough_layer(qwen_2_7b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
find_first_good_enough_layer_qwen_32b = find_first_good_enough_layer(qwen_32b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
find_first_good_enough_layer_llama3_8b = find_first_good_enough_layer(llama3_8b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
find_first_good_enough_layer_llama3_70b = find_first_good_enough_layer(llama3_70b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
find_first_good_enough_layer_mistral_8b = find_first_good_enough_layer(mistral_8b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")
find_first_good_enough_layer_mistral_7b = find_first_good_enough_layer(mistral_7b_stats_df, metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc")

find_first_good_enough_layer_qwen_2_7b, find_first_good_enough_layer_qwen_32b, find_first_good_enough_layer_llama3_8b, find_first_good_enough_layer_llama3_70b, find_first_good_enough_layer_mistral_8b, find_first_good_enough_layer_mistral_7b
# Out:
# (14, 28, 10, 20, 10, 12)

# %%
find_first_good_enough_layer_qwen_2_7b / LAYER_COUNTS["qwen_2_7b_n_layers"], find_first_good_enough_layer_qwen_32b / LAYER_COUNTS["qwen_32b_n_layers"], find_first_good_enough_layer_llama3_8b / LAYER_COUNTS["llama3_8b_n_layers"], find_first_good_enough_layer_llama3_70b / LAYER_COUNTS["llama3_70b_n_layers"], find_first_good_enough_layer_mistral_8b / LAYER_COUNTS["mistral_8b_n_layers"], find_first_good_enough_layer_mistral_7b / LAYER_COUNTS["mistral_7b_n_layers"]
# Out:
# (0.5, 0.4375, 0.3125, 0.25, 0.2777777777777778, 0.375)

# %%
def plot_in_dataset_performance_across_layers(model_stats_dict, metric_name, figsize=(6, 4), save_path=None):
    fig, axes = plt.subplots(
        len(model_stats_dict),
        1,
        figsize=figsize,
        constrained_layout=True
    )
    if len(model_stats_dict) == 1:
        axes = [axes]
        
    for i, (ax, model_name) in enumerate(zip(axes, model_stats_dict.keys())):
        stats_df = model_stats_dict[model_name]["stats_df"].copy()

        assert stats_df["input_type_train"].nunique() == 1, f"Input type train is not unique for {model_name}"
        assert stats_df["input_type_test"].nunique() == 1, f"Input type test is not unique for {model_name}"
        assert stats_df["prompt_id_train"].nunique() == 1, f"Prompt id train is not unique for {model_name}, {stats_df['prompt_id_train'].unique()=}"
        assert stats_df["prompt_id_test"].nunique() == 1, f"Prompt id test is not unique for {model_name}"
        assert not stats_df.empty, f"Stats df is empty for {model_name}"

        stats_df = stats_df[stats_df["dataset_id_train"] == stats_df["dataset_id_test"]]
        stats_df["model_name"] = model_name
        stats_df = stats_df[["model_name", "fold", "layer", "dataset_id_train", "dataset_id_test", metric_name]]
        stats_df_averaged = stats_df.groupby(["model_name", "layer", "dataset_id_train", "dataset_id_test"]).mean().reset_index()

        # Keep track of dataset index across all subplots
        for dataset_idx, (dataset_id, dataset_df) in enumerate(stats_df_averaged.groupby("dataset_id_train")):
            sns.lineplot(
                data=dataset_df,
                x="layer",
                y=metric_name,
                label=DATASET_NAME_MAP[dataset_id],
                ax=ax,
                linewidth=2,
                marker=DATASET_MARKERS[dataset_id],
                markersize=5,
                markerfacecolor=DATASET_COLORS[dataset_id],
                color=DATASET_COLORS[dataset_id],
                legend=True
            )

        # Add vertical line for first good enough layer
        first_good_enough_layer = model_stats_dict[model_name]["first_good_enough_layer"]
        ax.axvline(x=first_good_enough_layer, color='gray', linestyle=':', alpha=0.8, linewidth=2, label='First good enough layer', zorder=-1)
        
        # Add vertical line for best layer
        best_layer = model_stats_dict[model_name]["best_layer"] 
        ax.axvline(x=best_layer, color='black', linestyle='-', alpha=0.8, linewidth=2, label='Best layer', zorder=-1)

        ax.set_xlim(0, stats_df["layer"].max() + 1)
        ax.set_ylim(0.45, 1)
            
        ax.grid(True, linestyle='--', alpha=0.7)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.tick_params(axis='both', which='major', labelsize=9)

        if len(axes) > 1:
            ax.set_ylabel(model_name)
            if i == 0:
                ax.set_title("In-Distribution Test ROC AUC vs Layer")
            else:
                ax.set_title("")
            
            if i == len(axes) - 1:
                ax.set_xlabel("Layer")
            else:
                ax.set_xlabel("")
        else:
            ax.set_xlabel("Layer")
            ax.set_ylabel("Test ROC AUC")
            ax.set_title(f"{model_name} - Test ROC AUC vs Layer")

    # Get legend handles and labels from first subplot
    handles, labels = axes[0].get_legend_handles_labels()
    
    # Remove individual legends
    for ax in axes:
        ax.get_legend().remove()
        
    # Add single legend outside all subplots
    fig.legend(
        handles,
        labels,
        loc='center right',
        bbox_to_anchor=(1.15, 0.5),
        title='Dataset',
        frameon=True,
    )

    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0.1, dpi=300)
    plt.show()



plot_in_dataset_performance_across_layers(
    {
        "Mistral 7b": {"stats_df": mistral_7b_stats_df, "best_layer": best_layer_mistral_7b, "first_good_enough_layer": find_first_good_enough_layer_mistral_7b},
        "Ministral 8b": {"stats_df": mistral_8b_stats_df, "best_layer": best_layer_mistral_8b, "first_good_enough_layer": find_first_good_enough_layer_mistral_8b},
        "Qwen 2.5 7b": {"stats_df": qwen_2_7b_stats_df, "best_layer": best_layer_qwen_2_7b, "first_good_enough_layer": find_first_good_enough_layer_qwen_2_7b},
        "Qwen 32b": {"stats_df": qwen_32b_stats_df, "best_layer": best_layer_qwen_32b, "first_good_enough_layer": find_first_good_enough_layer_qwen_32b},
        "Llama 3.1 8b": {"stats_df": llama3_8b_stats_df, "best_layer": best_layer_llama3_8b, "first_good_enough_layer": find_first_good_enough_layer_llama3_8b},
        "Llama 3.3 70b": {"stats_df": llama3_70b_stats_df, "best_layer": best_layer_llama3_70b, "first_good_enough_layer": find_first_good_enough_layer_llama3_70b},
    },
    metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc",
    figsize=(6, 10),
    save_path="auc_across_layers_all_models.pdf"
)

plot_in_dataset_performance_across_layers(
    {
        "Llama 3.3 70b": {"stats_df": llama3_70b_stats_df, "best_layer": best_layer_llama3_70b, "first_good_enough_layer": find_first_good_enough_layer_llama3_70b},
    },
    metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc",
    figsize=(6, 4),
    save_path="auc_across_layers_llama_70b.pdf"
)
# Out:
# /var/folders/qd/cz9h19sd335142892r1531f40000gn/T/ipykernel_75749/2064422535.py:90: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right
# /var/folders/qd/cz9h19sd335142892r1531f40000gn/T/ipykernel_75749/2064422535.py:90: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right

# %%
def plot_in_dataset_performance_across_layers_all_models_one_plot(
        model_stats_dict,
        metric_name,
        figsize=(6, 4),
        save_path=None
    ):
    fig, ax = plt.subplots(
        1,
        1,
        figsize=figsize,
        constrained_layout=True
    )
        
    for model_name in model_stats_dict.keys():
        print(f"{model_name=}")
        stats_df = model_stats_dict[model_name]["stats_df"].copy()

        assert stats_df["input_type_train"].nunique() == 1, f"Input type train is not unique for {model_name}"
        assert stats_df["input_type_test"].nunique() == 1, f"Input type test is not unique for {model_name}"
        assert stats_df["prompt_id_train"].nunique() == 1, f"Prompt id train is not unique for {model_name}, {stats_df['prompt_id_train'].unique()=}"
        assert stats_df["prompt_id_test"].nunique() == 1, f"Prompt id test is not unique for {model_name}"
        assert not stats_df.empty, f"Stats df is empty for {model_name}"

        stats_df = stats_df[stats_df["dataset_id_train"] == stats_df["dataset_id_test"]]
        stats_df = stats_df[stats_df["dataset_id_train"] == "trivia_qa_2_60k"]
        stats_df["model_name"] = model_name
        stats_df = stats_df[["model_name", "fold", "layer", "dataset_id_train", "dataset_id_test", metric_name]]
        stats_df_averaged = stats_df.groupby(["model_name", "layer", "dataset_id_train", "dataset_id_test"]).mean().reset_index()

        stats_df_averaged["layer_fraction"] = stats_df_averaged["layer"] / model_stats_dict[model_name]["n_layers"]
        # Keep track of dataset index across all subplots
        ax = sns.lineplot(
            data=stats_df_averaged,
            x="layer_fraction",
            y=metric_name,
            linewidth=2,
            label=model_name,
            # marker=DATASET_MARKERS[dataset_id],
            markersize=5,
            # markerfacecolor=DATASET_COLORS[dataset_id],
            # color=DATASET_COLORS[dataset_id],
            # legend=True,
            ax=ax,
        )

        # # Add vertical line for first good enough layer
        # first_good_enough_layer = model_stats_dict[model_name]["first_good_enough_layer"]
        # ax.axvline(x=first_good_enough_layer, color='gray', linestyle=':', alpha=0.8, linewidth=2, label='First good enough layer', zorder=-1)
        
        # # Add vertical line for best layer
        # best_layer = model_stats_dict[model_name]["best_layer"] 
        # best_layer_fraction = best_layer / model_stats_dict[model_name]["n_layers"]
        # ax.axvline(
        #     x=best_layer_fraction, 
        #     # color='black',
        #     color=ax.lines[-1].get_color(),
        #     linestyle='--',
        #     alpha=0.5,
        #     linewidth=2,
        #     label='Best layer',
        #     zorder=-1
        # )

    ax.set_xlim(0, 1)
    ax.set_ylim(0.45, 1)
        
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(axis='both', which='major', labelsize=9)

    ax.set_xlabel("Layer / Total Layers")
    ax.set_ylabel("Test ROC AUC")
    ax.set_title(f"{model_name} - Test ROC AUC on TriviaQA 2 60k vs Layer")

    # # Get legend handles and labels from first subplot
    # handles, labels = axes[0].get_legend_handles_labels()
    
    # # Remove individual legends
    # for ax in axes:
    #     ax.get_legend().remove()
        
    # # Add single legend outside all subplots
    # fig.legend(
    #     handles,
    #     labels,
    #     loc='center right',
    #     bbox_to_anchor=(1.15, 0.5),
    #     title='Dataset',
    #     frameon=True,
    # )

    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0.1, dpi=300)
    plt.show()



plot_in_dataset_performance_across_layers_all_models_one_plot(
    {
        "Mistral 7b": {"stats_df": mistral_7b_stats_df, "best_layer": best_layer_mistral_7b, "first_good_enough_layer": find_first_good_enough_layer_mistral_7b, "n_layers": LAYER_COUNTS["mistral_7b_n_layers"]},
        "Ministral 8b": {"stats_df": mistral_8b_stats_df, "best_layer": best_layer_mistral_8b, "first_good_enough_layer": find_first_good_enough_layer_mistral_8b, "n_layers": LAYER_COUNTS["mistral_8b_n_layers"]},
        "Qwen 2.5 7b": {"stats_df": qwen_2_7b_stats_df, "best_layer": best_layer_qwen_2_7b, "first_good_enough_layer": find_first_good_enough_layer_qwen_2_7b, "n_layers": LAYER_COUNTS["qwen_2_7b_n_layers"]},
        "Qwen 32b": {"stats_df": qwen_32b_stats_df, "best_layer": best_layer_qwen_32b, "first_good_enough_layer": find_first_good_enough_layer_qwen_32b, "n_layers": LAYER_COUNTS["qwen_32b_n_layers"]},
        "Llama 3.1 8b": {"stats_df": llama3_8b_stats_df, "best_layer": best_layer_llama3_8b, "first_good_enough_layer": find_first_good_enough_layer_llama3_8b, "n_layers": LAYER_COUNTS["llama3_8b_n_layers"]},
        "Llama 3.3 70b": {"stats_df": llama3_70b_stats_df, "best_layer": best_layer_llama3_70b, "first_good_enough_layer": find_first_good_enough_layer_llama3_70b, "n_layers": LAYER_COUNTS["llama3_70b_n_layers"]},    
    },
    metric_name="direction__center_from_origin_True__classifier_cut_zero__test_roc_auc",
    figsize=(8, 4),
    save_path="auc_across_layers_all_models_in_one_plot_trivia_qa_2_60k.pdf"
)
# Out:
# model_name='Mistral 7b'
# model_name='Ministral 8b'
# model_name='Qwen 2.5 7b'
# model_name='Qwen 32b'
# model_name='Llama 3.1 8b'
# model_name='Llama 3.3 70b'
# /var/folders/qd/cz9h19sd335142892r1531f40000gn/T/ipykernel_75749/2276309926.py:93: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0, 0, 0.85, 1])  # Make space on the right
